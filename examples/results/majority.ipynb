# %%
from matplotlib import pyplot as plt
import numpy as np

from synet.networks import random_network
from synet.process import MajorityProcess
from synet.utils import apply_process, apply_measures
from synet.visualization import plot_process_results, plot_measure_results
from synet.visualization import plot_process_v_measure, plot_pvm_dt, plot_bootstrap_sim

# %%
n_networks = 100
process_dt = 250
n_events = 5000
np.random.seed(1287364)

# %%
majority = MajorityProcess()

# %%
# %%time
networks = [random_network(n_events=n_events) for _ in range(n_networks)]
# Out:
# CPU times: user 13.6 s, sys: 0 ns, total: 13.6 s
# Wall time: 13.6 s

# %%
# %%time
process_results = apply_process(networks, process=majority, dt=process_dt, n_sim=128, n_jobs=32)
# Out:
# CPU times: user 3.36 s, sys: 11.4 s, total: 14.8 s
# Wall time: 16.6 s

# %%
# %%time
measure_results = apply_measures(networks, max_dt=100)
# Out:
# CPU times: user 2min 39s, sys: 0 ns, total: 2min 39s
# Wall time: 2min 39s

# %%
#plot_bootstrap_sim(process_results, measure_results)

# %%
plot_process_results(process_results)

# %%
plot_process_v_measure(process_results, measure_results)

# %%
plot_pvm_dt(process_results, measure_results)
# Out:
# /home/qubix/.local/lib/python3.9/site-packages/scipy/stats/stats.py:4264: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
